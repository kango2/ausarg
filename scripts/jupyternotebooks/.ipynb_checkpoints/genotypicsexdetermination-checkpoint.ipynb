# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt

# Load data
xx_ratios = np.loadtxt("/g/data/te53/variantcall/workflowdev/shortread/genotypicsexdetection/ratio/chrX-XXratios.txt")
xy_ratios = np.loadtxt("/g/data/te53/variantcall/workflowdev/shortread/genotypicsexdetection/ratio/chrX-XYratios.txt")

# Calculate statistics
xx_mean = np.mean(xx_ratios)
xx_std_dev = np.std(xx_ratios)
xy_mean = np.mean(xy_ratios)
xy_std_dev = np.std(xy_ratios)

# Plot histograms for XX and XY ratios with 3 standard deviation lines
plt.figure(figsize=(12, 6))

# Histogram for XX ratios
plt.hist(xx_ratios, bins=20, alpha=0.7, label="XX Ratios", color='blue', density=True)

# Histogram for XY ratios
plt.hist(xy_ratios, bins=20, alpha=0.7, label="XY Ratios", color='green', density=True)

# Add mean lines
plt.axvline(xx_mean, color='blue', linestyle='dashed', linewidth=2, label="XX Mean")
plt.axvline(xy_mean, color='green', linestyle='dashed', linewidth=2, label="XY Mean")

# Add 3 standard deviation lines for XX
plt.axvline(xx_mean + 3 * xx_std_dev, color='blue', linestyle='dotted', linewidth=2, label="XX +3 Std Dev")
plt.axvline(xx_mean - 3 * xx_std_dev, color='blue', linestyle='dotted', linewidth=2, label="XX -3 Std Dev")

# Add 3 standard deviation lines for XY
plt.axvline(xy_mean + 3 * xy_std_dev, color='green', linestyle='dotted', linewidth=2, label="XY +3 Std Dev")
plt.axvline(xy_mean - 3 * xy_std_dev, color='green', linestyle='dotted', linewidth=2, label="XY -3 Std Dev")

# Labels and legend
plt.title("Ratio Distribution of chrX mapped reads in XX and XY samples")
plt.xlabel("Ratio")
plt.ylabel("Density")
plt.legend()

# Show plot
plt.show()

# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt

# Load data
xx_ratios = np.loadtxt("/g/data/te53/variantcall/workflowdev/shortread/genotypicsexdetection/ratio/chrY-XXratios.txt")
xy_ratios = np.loadtxt("/g/data/te53/variantcall/workflowdev/shortread/genotypicsexdetection/ratio/chrY-XYratios.txt")

# Calculate statistics
xx_mean = np.mean(xx_ratios)
xx_std_dev = np.std(xx_ratios)
xy_mean = np.mean(xy_ratios)
xy_std_dev = np.std(xy_ratios)

# Plot histograms for XX and XY ratios with 3 standard deviation lines
plt.figure(figsize=(12, 6))

# Histogram for XX ratios
plt.hist(xx_ratios, bins=20, alpha=0.7, label="XX Ratios", color='blue', density=True)

# Histogram for XY ratios
plt.hist(xy_ratios, bins=20, alpha=0.7, label="XY Ratios", color='green', density=True)

# Add mean lines
plt.axvline(xx_mean, color='blue', linestyle='dashed', linewidth=2, label="XX Mean")
plt.axvline(xy_mean, color='green', linestyle='dashed', linewidth=2, label="XY Mean")

# Add 3 standard deviation lines for XX
plt.axvline(xx_mean + 3 * xx_std_dev, color='blue', linestyle='dotted', linewidth=2, label="XX +3 Std Dev")
plt.axvline(xx_mean - 3 * xx_std_dev, color='blue', linestyle='dotted', linewidth=2, label="XX -3 Std Dev")

# Add 3 standard deviation lines for XY
plt.axvline(xy_mean + 3 * xy_std_dev, color='green', linestyle='dotted', linewidth=2, label="XY +3 Std Dev")
plt.axvline(xy_mean - 3 * xy_std_dev, color='green', linestyle='dotted', linewidth=2, label="XY -3 Std Dev")

# Labels and legend
plt.title("Ratio Distribution of chrY mapped reads in XX and XY samples")
plt.xlabel("Ratio")
plt.ylabel("Density")
plt.legend()

# Show plot
plt.show()

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, classification_report, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Load the data
def load_data():
    xx_file = "/g/data/te53/variantcall/workflowdev/shortread/genotypicsexdetection/ratio/chrY-XX.txt"
    xy_file = "/g/data/te53/variantcall/workflowdev/shortread/genotypicsexdetection/ratio/chrY-XY.txt"
    unk_file = "/g/data/te53/variantcall/workflowdev/shortread/genotypicsexdetection/ratio/chrY-unk.txt"

    xx_data = pd.read_csv(xx_file, header=None, names=["ratio"])
    xx_data["label"] = "XX"

    xy_data = pd.read_csv(xy_file, header=None, names=["ratio"])
    xy_data["label"] = "XY"

    unk_data = pd.read_csv(unk_file, header=None, names=["ratio"])
    unk_data["label"] = "unk"  # Optionally include

    # Combine datasets (exclude 'unk' for training)
    data = pd.concat([xx_data, xy_data], ignore_index=True)
    return data

# Load and preprocess data
data = load_data()
data["label"] = data["label"].map({"XX": 0, "XY": 1})  # Map labels to binary values

# Split data into training and testing sets
X = data["ratio"].values.reshape(-1, 1)
y = data["label"].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train a logistic regression classifier
classifier = LogisticRegression()
classifier.fit(X_train, y_train)

# Predict on the test set
y_pred = classifier.predict(X_test)

# Evaluate performance
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# Plot confusion matrix
ConfusionMatrixDisplay.from_estimator(classifier, X_test, y_test, display_labels=["XX", "XY"])
plt.title("Confusion Matrix")
plt.show()

# Plot decision boundary
x_vals = np.linspace(min(X), max(X), 1000).reshape(-1, 1)
y_vals = classifier.predict_proba(x_vals)[:, 1]

plt.figure(figsize=(8, 6))
plt.scatter(X, y, c=y, cmap="bwr", edgecolors="k", label="Data Points")
plt.plot(x_vals, y_vals, color="green", label="Decision Boundary")
plt.axhline(0.5, linestyle="--", color="gray", label="Threshold (0.5)")
plt.title("Logistic Regression Decision Boundary")
plt.xlabel("chrY Ratio")
plt.ylabel("Probability of XY")
plt.legend()
plt.show()
# Out:
# /g/data/if89/apps/pythonlib/3.9.2/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /g/data/if89/apps/pythonlib/3.9.2/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /g/data/if89/apps/pythonlib/3.9.2/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
